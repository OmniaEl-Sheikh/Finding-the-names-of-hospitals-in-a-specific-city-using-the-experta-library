# %%
from tkinter import *
from experta import *
class find_hospital(KnowledgeEngine):
	@DefFacts()
	def _initial_action(self):
		gui_form1 = Tk()
        
		gui_form1.title("Medical system")
		gui_form1.config(background='wheat')
		fr1 = Frame(width='900', height='500', background='wheat')
		fr1.place(x=10, y=10)
		gui_form1.geometry("900x700")
		lb0 = Label(gui_form1, justify='center', font=5,text="Hi! We will help you to know the hospitals around you.\nPlease select the country you would like to inquire about.",bg="#123456", fg="#fff",width="800")
		lb0.pack()
###############################################################################
		lb1 = Label(gui_form1,text="Alexandria:",bg='white', font=5)
		en1 = Entry(gui_form1, justify='center', font=5)
		lb1.place(x=160,y=100)
		en1.place(x=450,y=100)
###############################################################################
		lb2 = Label(gui_form1,text="Ismailia:",bg='white', font=5)
		en2 = Entry(gui_form1, justify='center', font=5)
		lb2.place(x=160,y=140)
		en2.place(x=450,y=140)
###############################################################################
		lb3 = Label(gui_form1,text="Aswan:",bg='white', font=5)
		en3 = Entry(gui_form1, justify='center', font=5)
		lb3.place(x=160,y=180)
		en3.place(x=450,y=180)
# ###############################################################################
		lb4 = Label(gui_form1,text="Asyut:",bg='white', font=5)
		en4 = Entry(gui_form1, justify='center', font=5)
		lb4.place(x=160,y=220)
		en4.place(x=450,y=220)
# ###############################################################################
		lb5 = Label(gui_form1,text="Giza:",bg='white', font=5)
		en5 = Entry(gui_form1, justify='center', font=5)
		lb5.place(x=160,y=260)
		en5.place(x=450,y=260)
# ###############################################################################
		lb6 = Label(gui_form1,text="Dakahlia:",bg='white', font=5)
		en6 = Entry(gui_form1, justify='center', font=5)
		lb6.place(x=160,y=300)
		en6.place(x=450,y=300)
# ###############################################################################
		lb7 = Label(gui_form1,text="Damietta:",bg='white', font=5)
		en7 = Entry(gui_form1, justify='center', font=5)
		lb7.place(x=160,y=340)
		en7.place(x=450,y=340)
# ###############################################################################
		lb8 = Label(gui_form1,text="Qalyubia:",bg='white', font=5)
		en8 = Entry(gui_form1, justify='center', font=5)
		lb8.place(x=160,y=380)
		en8.place(x=450,y=380)
# ###############################################################################
		lb9 = Label(gui_form1,text="Sohag:",bg='white', font=5)
		en9 = Entry(gui_form1, justify='center', font=5)
		lb9.place(x=160,y=420)
		en9.place(x=450,y=420)
# ###############################################################################
		lb10 = Label(gui_form1,text="Qena:",bg='white', font=5)
		en10 = Entry(gui_form1, justify='center', font=5)
		lb10.place(x=160,y=460)
		en10.place(x=450,y=460)
# ###############################################################################
		lb11 = Label(gui_form1,text="Port_Said:",bg='white', font=5)
		en11= Entry(gui_form1, justify='center', font=5)
		lb11.place(x=160,y=500)
		en11.place(x=450,y=500)
# ###############################################################################
		lb12 = Label(gui_form1,text="Minya:",bg='white', font=5)
		en12 = Entry(gui_form1, justify='center', font=5)
		lb12.place(x=160,y=540)
		en12.place(x=450,y=540)
# ###############################################################################
		lb13 = Label(gui_form1,text="Bani_Sweif:",bg='white', font=5)
		en13 = Entry(gui_form1, justify='center', font=5)
		lb13.place(x=160,y=580)
		en13.place(x=450,y=580)
##############################################################################
		def get_values():
			#lb2["text"] = en2.get()
			self.declare(Fact(Alexandria=en1.get()))
			self.declare(Fact(Ismailia=en2.get()))
			self.declare(Fact(Aswan=en3.get()))
			self.declare(Fact(Asyut=en4.get()))
			self.declare(Fact(Giza=en5.get()))
			self.declare(Fact(Dakahlia=en6.get()))
			self.declare(Fact(Damietta=en7.get()))
			self.declare(Fact(Qalyubia=en8.get()))
			self.declare(Fact(Sohag=en9.get()))
			self.declare(Fact(Qena=en10.get()))
			self.declare(Fact(Port_Said=en11.get()))
			self.declare(Fact(Minya=en12.get()))
			self.declare(Fact(Bani_Sweif=en13.get()))
#############################################################################
		btn = Button(gui_form1,command=get_values,text="get_values",bg="#123456", fg="#fff", font=5)
		btn.place(x=320,y=650)
        

            
		gui_form1.mainloop()
		yield Fact(action="find_hospital")
        

###################################################################################################
##################################################################################################

	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_0(self):
		self.declare(Fact(hospital="You did not inquire about any region"))
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="yes"),Fact(Ismailia="yes"),Fact(Aswan="yes"),Fact(Asyut="yes"),Fact(Giza="yes"),Fact(Dakahlia="yes"),Fact(Damietta="yes"),Fact(Qalyubia="yes"),Fact(Sohag="yes"),Fact(Qena="yes"),Fact(Port_Said="yes"),Fact(Minya="yes"),Fact(Bani_Sweif="yes"))
	def result_1(self):
		self.declare(Fact(hospital="I have inquired about many areas, please be specific"))
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="yes"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_2(self):
		self.declare(Fact(hospital="مستشفى النزهة التخصصى\n مستشفى اسكندرية الدولى \n مستشفى المواساة \n مستشفى الطلبة"))        

	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="yes"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_3(self):
		self.declare(Fact(hospital="مستشفى الإسماعيلية العام\n مستشفى الحميات \n مستشفى جامعة قناة السويس \n مستشفى الزهور التخصصى"))        
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="yes"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_4(self):
		self.declare(Fact(hospital="مستشفى الهلال الاحمر التخصصى\n مستشفى اسوان للصحة النفسية \n مركز اسوان للقلب \n مركز اسوان للقلب"))
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="yes"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_5(self):
		self.declare(Fact(hospital="مستشفى النيل\n مستشفى العقاد \n مستشفى الندى \n مستشفى السلامة"))

	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="yes"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_6(self):
		self.declare(Fact(hospital="مستشفى الروضة الشريفة\n مستشفى الروان التخصصى \n مستشفى الرواد للعيون \n مستشفى الزمالك"))        
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="yes"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_7(self):
		self.declare(Fact(hospital="مستشفى طوارىء جامعة المنصورة\n مستشفى حواء \n مستشفى طيبة \n مستشفى مجمع الايمان"))
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="yes"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_8(self):
		self.declare(Fact(hospital="مستشفى العيون الدولى\n مستشفى دمياط التخصصى \nمستشفى جامعة الازهر \n مستشفى الهلال للتأمين الصحى"))
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="yes"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_9(self):
		self.declare(Fact(hospital="مستشفى بنها للصحة النفسية وعلاج الادمان\n مستشفى مصر الامل \nمستشفى بنها الجامعى \n مستشفى فريد حبيب"))        

	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="yes"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_10(self):
		self.declare(Fact(hospital="مستشفى مصر سوهاج\n مستشفى راشد التخصصى \nمستشفى الهلال \n مستشفى المعلمين"))        
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="yes"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_11(self):
		self.declare(Fact(hospital="مستشفى سان مارى\n مستشفى قنا الجامعى \nمستشفى الشفاء الدولى \n مستشفى قوص المركزى"))        

	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="yes"),Fact(Minya="no"),Fact(Bani_Sweif="no"))
	def result_12(self):
		self.declare(Fact(hospital="مستشفى بورسعيد العام\n مستشفى عصفور \nمستشفى المبرة \n مستشفى ال سليمان"))        
        
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="yes"),Fact(Bani_Sweif="no"))
	def result_13(self):
		self.declare(Fact(hospital="مستشفى دار الام التخصصى\n مستشفى المنيا الجامعى \nمستشفى الصفوة \n مستشفى المنيا للطب النفسى"))
                
	@Rule(Fact(action='find_hospital'),Fact(Alexandria="no"),Fact(Ismailia="no"),Fact(Aswan="no"),Fact(Asyut="no"),Fact(Giza="no"),Fact(Dakahlia="no"),Fact(Damietta="no"),Fact(Qalyubia="no"),Fact(Sohag="no"),Fact(Qena="no"),Fact(Port_Said="no"),Fact(Minya="no"),Fact(Bani_Sweif="yes"))
	def result_14(self):
		self.declare(Fact(hospital="مستشفى الطب النفسى ببنى سويف\n مستشفى اللؤلؤة \nمستشفى سمسطا المركزى \n مستشفى بنى سويف العام"))        


	@Rule(Fact(action='find_hospital'),Fact(hospital=MATCH.hospital))
	def a(self, hospital):
		print("")
		id_hospital = hospital
		gui_form2 = Tk()
		gui_form2.title("Medical system answer")
		gui_form2.geometry("800x200")
		lb0 = Label(gui_form2,text="the result is",bg="#123456", fg="#fff",width="800", font=5)
		lb0.pack()
		var = StringVar()
		var.set(id_hospital)
		lb1 = Label(gui_form2, textvariable = var,bg="#678954", fg="#fff",width="800",height="20", font=5)
		lb1.pack()

		gui_form2.mainloop()

engine = find_hospital()
while(1):
    engine.reset()  
    engine.run()  
    print("Would you like to inquire about another province??")
    if input() == "no":
        break;
# Out:
# WARNING:experta.watchers.ENGINE:Declaring fact before reset()
# Would you like to inquire about another province??
